# %%
import os
import tweepy
import pandas as pd

# %% [markdown]
# ## Tweepy
#
# Para acessar a API do twitter, deve-se acessar a área de desenvolvedor, criar uma aplicação e solicitar as credenciais de acesso. As células abaixo demonstram como fazer a conexão na API do twitter usando a biblioteca python Tweepy e retornar a lista de tweets na timeline do usuário.
#
# [Documentação do tweepy](https://tweepy.readthedocs.io/)

# %%
consumer_key = os.environ['CONSUMER_API_KEY']
consumer_secret = os.environ['CONSUMER_API_SECRET']
access_token = os.environ['ACCESS_TOKEN']
access_token_secret = os.environ['ACCESS_TOKEN_SECRET']

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# Recuperar tweets da timeline

# %%
public_tweets = api.home_timeline()

# %% [markdown]
# Criar um dicionário vazio para incluir os tweets.
# Passo necessário para criar um dataframe.

# %%
tweets = {'id':[],'author':[],'tweet':[],'created_at':[],'language':[],'n_retweets':[],'n_likes':[]}

# %%
for tweet in public_tweets:
    print("id: "+tweet.id_str)
    print("Autor: "+tweet.author.name)
    print("Tweet: "+tweet.text)
    print("Data de criação: "+tweet.created_at.strftime("%d/%m/%Y, %H:%M:%S"))
    print("Idioma: "+tweet.lang)
    print("Retweets: "+str(tweet.retweet_count))
    print("Curtidas: "+str(tweet.favorite_count))
    tweets['id'].append(tweet.id)
    tweets['author'].append(tweet.author.name)
    tweets['tweet'].append(tweet.text)
    tweets['created_at'].append(tweet.created_at)
    tweets['language'].append(tweet.lang)
    tweets['n_retweets'].append(tweet.retweet_count)
    tweets['n_likes'].append(tweet.favorite_count)
    print("==========================")
# Out:
# id: 1201640588765888512
# Autor: Origin
# Tweet: Starting today, #PvZBfN players will receive monthly rewards for being #OriginAccess members!
#
# Subscribers get 30K… https://t.co/bP95GhZHBE
# Data de criação: 02/12/2019, 23:13:36
# Idioma: en
# Retweets: 0
# Curtidas: 0
# ==========================
# id: 1201639171665932288
# Autor: Eduardo Benvenuti - Progenitor do Bilômetro
# Tweet: https://t.co/2LJyVktXUt
# Data de criação: 02/12/2019, 23:07:58
# Idioma: und
# Retweets: 3
# Curtidas: 124
# ==========================
# id: 1201638879348039681
# Autor: The Enemy 🎮
# Tweet: Além de premiar os principais jogos dos últimos meses, o The Game Awards é um evento marcado também pelos anúncios… https://t.co/TBgtHmpq3J
# Data de criação: 02/12/2019, 23:06:48
# Idioma: pt
# Retweets: 0
# Curtidas: 5
# ==========================
# id: 1201638394717200385
# Autor: GamesRadar+
# Tweet: Grab Darth Vader's lightsaber for just $13 and show Luke Skywalker the true power of the Dark Side… https://t.co/hSurBTb2s2
# Data de criação: 02/12/2019, 23:04:53
# Idioma: en
# Retweets: 1
# Curtidas: 5
# ==========================
# id: 1201637417620529152
# Autor: IGN
# Tweet: Watch this exclusive deleted scene from @GameofThrones Season 8, which reveals another grisly death during "The Lon… https://t.co/TgL3aJBD3l
# Data de criação: 02/12/2019, 23:01:00
# Idioma: en
# Retweets: 23
# Curtidas: 172
# ==========================
# id: 1201637226133803011
# Autor: PC Gamer
# Tweet: EVE Online's mobile spin-off is out now in open beta https://t.co/taHtsH62No https://t.co/IRaNubvYRZ
# Data de criação: 02/12/2019, 23:00:14
# Idioma: en
# Retweets: 4
# Curtidas: 19
# ==========================
# id: 1201637183624548352
# Autor: GamesRadar+
# Tweet: There's an hour left of Cyber Monday! These are the best last-minute deals for under £50 https://t.co/b3SwVwQmGm https://t.co/nq5IdTGjvS
# Data de criação: 02/12/2019, 23:00:04
# Idioma: en
# Retweets: 0
# Curtidas: 3
# ==========================
# ==========================
# id: 1201626652473737216
# Autor: GameSpot
# Tweet: RT @GameSpotDeals: Best discounts on Steam's Cyber Monday sale https://t.co/alJQhQN6nD https://t.co/Sam8bTB6I9
# Data de criação: 02/12/2019, 22:18:13
# Idioma: en
# Retweets: 4
# Curtidas: 0
# ==========================

# %% [markdown]
# Criação do dataframe

# %%
df = pd.DataFrame.from_dict(tweets)

# %%
df
# Out:
#                      id                                       author  \
# 0   1201640588765888512                                       Origin
# 1   1201639171665932288  Eduardo Benvenuti - Progenitor do Bilômetro
# 2   1201638879348039681                                  The Enemy 🎮
# 3   1201638394717200385                                  GamesRadar+
# 4   1201637417620529152                                          IGN
# 5   1201637226133803011                                     PC Gamer
# 6   1201637183624548352                                  GamesRadar+
# 7   1201635670206418950                                       MaxMRM
# 8   1201633670647431168                                          IGN
# 9   1201633405038927872                                  GamesRadar+
# 10  1201633381181743104                                         SEGA
# 11  1201633093171335168                                          IGN
# 12  1201632139382538244                                     PC Gamer
# 13  1201630230307393538                                     GameSpot
# 14  1201629887339077633                                          IGN
# 15  1201629674159386626                                  GamesRadar+
# 16  1201629616840024072                                        Steam
# 17  1201628857511493632                                       Konami
# 18  1201627118561574912                                     PC Gamer
# 19  1201626652473737216                                     GameSpot
#
#                                                 tweet          created_at  \
# 0   Starting today, #PvZBfN players will receive m... 2019-12-02 23:13:36
# 1                             https://t.co/2LJyVktXUt 2019-12-02 23:07:58
# 2   Além de premiar os principais jogos dos último... 2019-12-02 23:06:48
# 3   Grab Darth Vader's lightsaber for just $13 and... 2019-12-02 23:04:53
# 4   Watch this exclusive deleted scene from @Gameo... 2019-12-02 23:01:00
# 5   EVE Online's mobile spin-off is out now in ope... 2019-12-02 23:00:14
# 6   There's an hour left of Cyber Monday! These ar... 2019-12-02 23:00:04
# 7   LÃIVE!\n\nhttps://t.co/yucemIvbZO https://t.co... 2019-12-02 22:54:03
# 8   Speaking to BeTerrific at Toy Fair 2019, McFar... 2019-12-02 22:46:07
# 9   Listen up! The HyperX Cloud II Gaming Headset ... 2019-12-02 22:45:03
# 10  From producing and directing Super Monkey Ball... 2019-12-02 22:44:57
# 11  Get this shirt, we must 😍 https://t.co/Gnqpnjk3Qe 2019-12-02 22:43:49
# 12  Quantic Dream ordered to pay former employee o... 2019-12-02 22:40:01
# 13  RT @GameSpotDeals: Amazon's huge Cyber Monday ... 2019-12-02 22:32:26
# 14  MORTAL KOMBAT!!!\n\nThe excellent 3/4 scale Mo... 2019-12-02 22:31:05
# 15  This stunning 27-inch BenQ gaming monitor is $... 2019-12-02 22:30:14
# 16  🍂 #SteamAutumnSale Spotlight 🍂\nSave 50% on Th... 2019-12-02 22:30:00
# 17  RT @LucidSoundAudio: Who could pass up another... 2019-12-02 22:26:59
# 18  This MSI gaming laptop with a 4K screen and 32... 2019-12-02 22:20:04
# 19  RT @GameSpotDeals: Best discounts on Steam's C... 2019-12-02 22:18:13
#
#    language  n_retweets  n_likes
# 0        en           0        0
# 1       und           3      124
# 2        pt           0        5
# 3        en           1        5
# 4        en          23      172
# 5        en           4       19
# 6        en           0        3
# 7        vi          13       35
# 8        en          32      174
# 9        en           0        1
# 10       en          22      122
# 11       en          58      445
# 12       en           7       32
# 13       en           6        0
# 14       en          21      123
# 15       en           1        4
# 16       en          19      128
# 17       en           4        0
# 18       en           6       27
# 19       en           4        0

# %% [markdown]
# Salvar o dataframe em csv para uso posterior.

# %%
df.to_csv('dataframe.csv')
